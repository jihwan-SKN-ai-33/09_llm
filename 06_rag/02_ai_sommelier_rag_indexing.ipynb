# %% [markdown]
# # AI Sommelier RAG: 와인 리뷰 인덱싱
#
# 이 노트북은 RAG의 사전 준비 단계인 **인덱싱**을 다룬다. Wine Magazine 리뷰를 의미로 검색할 수 있게 변환해 Pinecone에 저장한다.
#
# ### 인덱싱 흐름
#
# `CSV 행 → Document → embedding vector → Pinecone index`
#
# ### 핵심 구성 요소
#
# - `Document`: 검색 본문 `page_content`와 출처 정보 `metadata`를 함께 담는다.
# - `Embedding`: 문서 본문의 의미를 숫자 vector로 변환한다.
# - `Pinecone index`: vector와 원문·metadata를 저장하고 검색한다.
# - `namespace`: 하나의 index 안에서 레코드를 논리적으로 구분한다.
#
# ### 인덱싱과 검색의 차이
#
# - 인덱싱: 문서를 미리 변환해 저장하는 작업이다.
# - Querying: 사용자 질문이 들어오면 관련 문서를 찾는 작업이다.
#
# 다음 노트북은 여기서 만든 `winemag-review-data` index를 조회한다. 검색 결과인 `list[Document]`는 와인 추천 Prompt의 context로 사용한다.

# %% [markdown]
# ## Pinecone이란
#
# Pinecone은 embedding vector를 저장하고 의미가 가까운 데이터를 검색하는 **관리형 Vector DB**이다. 사용자가 별도 데이터베이스 서버를 설치하지 않아도 Pinecone이 원격 저장소의 운영, 확장과 API 접속을 관리한다.
#
# ### Chroma와의 차이
#
# - `Chroma`: 개인 PC에서 빠르게 시작하기 좋은 로컬 Vector Store이다. 폴더에 저장하면 같은 PC에서 다시 열 수 있다.
# - `Pinecone`: 인터넷을 통해 접속하는 클라우드 Vector DB이다. 여러 실행 환경이 같은 index를 사용할 수 있지만 계정과 API Key가 필요하다.
#
# ### 이 실습에서 Pinecone이 하는 일
#
# `Document → OpenAI embedding vector → Pinecone index → 유사도 검색 → list[Document]`
#
# 1. `OpenAIEmbeddings`가 `Document.page_content`를 숫자 vector로 변환한다.
# 2. Pinecone index가 vector와 원문·metadata를 함께 저장한다.
# 3. 질문이 들어오면 같은 Embedding Model로 query vector를 만든다.
# 4. Pinecone이 가까운 vector를 찾고 연결된 Document를 반환한다.
#
# Pinecone은 LLM 답변을 생성하지 않는다. 검색된 `list[Document]`를 다음 RAG 단계에서 Prompt의 context로 전달한다. [Pinecone Quickstart](https://docs.pinecone.io/guides/get-started/quickstart)에서 전체 저장·검색 흐름을 확인할 수 있다.

# %% [markdown]
# ## 1. Pinecone 가입과 프로젝트 선택
#
# 먼저 [Pinecone Console](https://app.pinecone.io/)에 가입하고 로그인한다. Pinecone의 Index와 API Key는 프로젝트에 속하므로 수업에서 사용할 프로젝트를 먼저 정해야 한다.
#
# ### 준비 순서
#
# 1. Pinecone Console에 가입하고 로그인한다.
# 2. 수업에 사용할 프로젝트를 선택하거나 새 프로젝트를 만든다.
# 3. 이후 Index 생성과 API Key 발급을 모두 같은 프로젝트에서 진행한다.
#
# 프로젝트를 바꾸면 Index 목록과 API Key도 달라질 수 있다. 뒤에서 Index를 찾지 못하는 오류가 발생하면 현재 선택한 프로젝트부터 확인한다.

# %% [markdown]
# ## 2. 수업용 Pinecone Index 생성
#
# 이 실습은 Pinecone이 텍스트를 직접 임베딩하는 방식이 아니라, OpenAI가 만든 vector를 Pinecone에 저장하는 **외부 임베딩 방식**을 사용한다. 따라서 코드를 실행하기 전에 Pinecone Console에서 두 개의 dense index를 준비한다.
#
#
# ### 공통 설정
#
# - 방식: `Bring your own vectors` 또는 외부 embedding vector를 저장하는 설정
# - Vector type: `Dense`
# - Dimension: `1536`
# - Metric: `cosine`
# - 배포 방식: 계정에서 선택 가능한 Serverless cloud와 region
#
# `text-embedding-3-small`을 별도 `dimensions` 인자 없이 호출하면 1536차원 vector를 반환하므로 Index dimension도 1536이어야 한다. Dimension이 다르면 문서를 저장하거나 검색할 때 오류가 발생한다.
#
# ### Console에서 만드는 순서
#
# 1. Pinecone Console의 `Indexes`에서 `Create index`를 선택한다.
# 2. Index 이름에 `pinecone-first`를 입력한다.
# 3. 위 공통 설정으로 생성하고 상태가 `Ready`가 될 때까지 기다린다.
# 4. 같은 설정으로 `winemag-review-data`도 생성한다.
# 5. 두 Index가 현재 선택한 프로젝트에 생성되었는지 확인한다.
#
# 코드의 `DEMO_INDEX_NAME`과 `WINE_INDEX_NAME`은 이 이름을 그대로 사용한다. 다른 이름으로 만들었다면 코드의 상수도 같은 이름으로 바꿔야 한다. Index 생성 방식과 옵션은 [Pinecone Index 공식 가이드](https://docs.pinecone.io/guides/index-data/create-an-index)에서 확인할 수 있다.

# %% [markdown]
# ## 3. Pinecone API Key 발급과 `.env` 등록
#
# API Key는 Python 코드가 Pinecone 프로젝트에 접속할 때 사용하는 인증 정보이다. 앞에서 Index를 만든 프로젝트에서 API Key를 발급해야 코드가 해당 Index를 찾을 수 있다.
#
# ### API Key 발급 순서
#
# 1. Pinecone Console에서 앞서 Index를 만든 프로젝트를 선택한다.
# 2. `API keys` 메뉴를 연다.
# 3. `Create API key`를 선택하고 `skn-llm-lecture`처럼 용도를 알 수 있는 이름을 입력한다.
# 4. 생성된 API Key를 복사한다.
# 5. PyCharm 프로젝트의 `.env` 파일에 아래와 같이 등록한다.
#
# ```text
# OPENAI_API_KEY=your_openai_api_key
# OPENAI_EMBEDDING_MODEL=text-embedding-3-small
# PINECONE_API_KEY=your_pinecone_api_key
# ```
#
# - `PINECONE_API_KEY`는 앞에서 Index를 만든 프로젝트의 Key를 사용한다.
# - `.env`는 Git에 올리지 않는다.
# - API Key를 코드, 출력, 화면 캡처에 포함하지 않는다.
# - 키가 노출되면 Pinecone Console에서 삭제하고 새로 발급한다.
#
# 자세한 발급·삭제 절차는 [Pinecone API Key 공식 가이드](https://docs.pinecone.io/guides/projects/manage-api-keys)에서 확인할 수 있다.

# %% [markdown]
# ## 패키지 준비
#
# 이 실습은 LangChain의 `Document`와 OpenAI embedding을 Pinecone에 연결한다.
#
# - `langchain`: `Document`와 Retriever 같은 공통 인터페이스를 제공한다.
# - `langchain-openai`: OpenAI embedding 모델을 연결한다.
# - `langchain-pinecone`: LangChain `Document`와 Pinecone을 연결한다.
# - `pinecone`: Pinecone index에 접속하는 공식 SDK이다.
# - `langchain-community`: CSV 행을 `Document`로 읽는 `CSVLoader`를 제공한다.
# - `gdown`: 수업용 공개 CSV를 Google Drive에서 내려받는다.
# - `python-dotenv`: `.env`의 API 설정을 환경 변수로 불러온다.

# %%
# %pip install -U langchain langchain-openai langchain-pinecone langchain-community pinecone gdown python-dotenv
# Out:
# Requirement already satisfied: langchain in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (1.3.14)
# Collecting langchain
#   Downloading langchain-1.3.15-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: langchain-openai in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (1.4.3)
# Requirement already satisfied: langchain-pinecone in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (0.2.13)
# Requirement already satisfied: langchain-community in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (0.4.2)
# Requirement already satisfied: pinecone in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (7.3.0)
# Collecting pinecone
#   Downloading pinecone-9.1.0-cp310-abi3-win_amd64.whl.metadata (6.3 kB)
# Requirement already satisfied: gdown in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (6.1.0)
# Requirement already satisfied: python-dotenv in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (1.2.2)
# Collecting langchain-core<2.0.0,>=1.5.4 (from langchain)
#   Downloading langchain_core-1.5.4-py3-none-any.whl.metadata (4.8 kB)
# Collecting langgraph<1.3.0,>=1.2.11 (from langchain)
#   Downloading langgraph-1.2.11-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from langchain) (2.13.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from langchain-core<2.0.0,>=1.5.4->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from langchain-core<2.0.0,>=1.5.4->langchain) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from langchain-core<2.0.0,>=1.5.4->langchain) (0.10.16)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from langchain-core<2.0.0,>=1.5.4->langchain) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from langchain-core<2.0.0,>=1.5.4->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from langchain-core<2.0.0,>=1.5.4->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from langchain-core<2.0.0,>=1.5.4->langchain) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from langchain-core<2.0.0,>=1.5.4->langchain) (0.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.5.4->langchain) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (0.4.2)
# Requirement already satisfied: xxhash>=3.5.0 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (3.7.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.11->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (3.11.9)
# Requirement already satisfied: websockets<16,>=14 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (15.0.1)
# Requirement already satisfied: anyio>=3.5.0 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.4->langchain) (4.14.2)
# Requirement already satisfied: distro>=1.7.0 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.4->langchain) (1.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.4->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.4->langchain) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.4->langchain) (1.3.1)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.4->langchain) (0.25.0)
# Requirement already satisfied: certifi in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (1.0.9)
# Requirement already satisfied: idna in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (3.18)
# Requirement already satisfied: h11>=0.16 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: openai<3.0.0,>=2.45.0 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from langchain-openai) (2.52.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from langchain-openai) (0.13.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from openai<3.0.0,>=2.45.0->langchain-openai) (0.16.0)
# Requirement already satisfied: tqdm>4 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from openai<3.0.0,>=2.45.0->langchain-openai) (4.70.0)
# Requirement already satisfied: regex in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2026.7.19)
# Requirement already satisfied: numpy!=2.0.2,>=1.26.4 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from langchain-pinecone) (2.5.1)
# Requirement already satisfied: simsimd>=5.9.11 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from langchain-pinecone) (6.5.16)
# Requirement already satisfied: pinecone-plugin-assistant<2.0.0,>=1.6.0 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from pinecone) (1.8.0)
# Requirement already satisfied: pinecone-plugin-interface<0.0.8,>=0.0.7 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from pinecone) (0.0.7)
# Requirement already satisfied: python-dateutil>=2.5.3 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from pinecone) (2.9.0.post0)
# Requirement already satisfied: urllib3>=1.26.5 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from pinecone) (2.7.0)
# Requirement already satisfied: aiohttp>=3.9.0 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (3.14.3)
# Requirement already satisfied: aiohttp-retry<3.0.0,>=2.9.1 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (2.9.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.4->langchain) (3.4.9)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from langchain-community) (1.0.8)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from langchain-community) (2.14.2)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from langchain-community) (2.0.51)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (1.24.5)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (1.1.2)
# Requirement already satisfied: greenlet>=1 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.5.5)
# Requirement already satisfied: beautifulsoup4 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from gdown) (4.15.0)
# Requirement already satisfied: filelock in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from gdown) (3.32.2)
# Requirement already satisfied: six>=1.5 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from python-dateutil>=2.5.3->pinecone) (1.17.0)
# Requirement already satisfied: colorama in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from tqdm>4->openai<3.0.0,>=2.45.0->langchain-openai) (0.4.6)
# Requirement already satisfied: soupsieve>=1.6.1 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from beautifulsoup4->gdown) (2.9.1)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages (from requests[socks]->gdown) (1.7.1)
# Downloading langchain-1.3.15-py3-none-any.whl (147 kB)
# Downloading langchain_core-1.5.4-py3-none-any.whl (565 kB)
#    ---------------------------------------- 0.0/565.1 kB ? eta -:--:--
#    ---------------------------------------- 565.1/565.1 kB 4.9 MB/s  0:00:00
# Downloading langgraph-1.2.11-py3-none-any.whl (248 kB)
# Installing collected packages: langchain-core, langgraph, langchain
#
#   Attempting uninstall: langchain-core
#
#     Found existing installation: langchain-core 1.5.3
#
#     Uninstalling langchain-core-1.5.3:
#
#    ---------------------------------------- 0/3 [langchain-core]
#       Successfully uninstalled langchain-core-1.5.3
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#   Attempting uninstall: langgraph
#    ---------------------------------------- 0/3 [langchain-core]
#     Found existing installation: langgraph 1.2.10
#    ---------------------------------------- 0/3 [langchain-core]
#     Uninstalling langgraph-1.2.10:
#    ---------------------------------------- 0/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langgraph]
#       Successfully uninstalled langgraph-1.2.10
#    ------------- -------------------------- 1/3 [langgraph]
#    ------------- -------------------------- 1/3 [langgraph]
#    ------------- -------------------------- 1/3 [langgraph]
#    ------------- -------------------------- 1/3 [langgraph]
#    ------------- -------------------------- 1/3 [langgraph]
#    ------------- -------------------------- 1/3 [langgraph]
#    ------------- -------------------------- 1/3 [langgraph]
#   Attempting uninstall: langchain
#    ------------- -------------------------- 1/3 [langgraph]
#     Found existing installation: langchain 1.3.14
#    ------------- -------------------------- 1/3 [langgraph]
#     Uninstalling langchain-1.3.14:
#    ------------- -------------------------- 1/3 [langgraph]
#       Successfully uninstalled langchain-1.3.14
#    ------------- -------------------------- 1/3 [langgraph]
#    -------------------------- ------------- 2/3 [langchain]
#    -------------------------- ------------- 2/3 [langchain]
#    -------------------------- ------------- 2/3 [langchain]
#    ---------------------------------------- 3/3 [langchain]
#
# Successfully installed langchain-1.3.15 langchain-core-1.5.4 langgraph-1.2.11
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## `.env`의 API 설정 불러오기
#
# 앞에서 `.env`에 등록한 값을 `load_dotenv()`로 현재 Python 프로세스의 환경 변수에 불러온다. API Key의 실제 값은 출력하지 않는다.
#
# ### 이어지는 코드에서 사용하는 설정
#
# - `OPENAI_API_KEY`: 문서와 query를 embedding할 때 사용한다.
# - `OPENAI_EMBEDDING_MODEL`: 사용할 embedding 모델 이름이다.
# - `PINECONE_API_KEY`: Pinecone index에 접속할 때 사용한다.
#
# ### 반드시 일치해야 하는 설정
#
# - 문서 인덱싱과 query 검색은 같은 embedding 모델을 사용한다.
# - Pinecone index의 차원은 embedding vector의 차원과 같아야 한다.
# - 이 실습은 `text-embedding-3-small`과 1536차원 Index를 기준으로 사용한다.

# %%
import os

from dotenv import load_dotenv

load_dotenv()

DEMO_INDEX_NAME = 'pinecone-first'

WINE_INDEX_NAME = 'winemag-review-data'

# %% [markdown]
# ## 작은 문서로 Pinecone 인덱싱 흐름 확인하기
#
# Pinecone은 embedding vector를 저장하고 유사도 검색을 수행하는 관리형 Vector DB이다.
#
# ### Pinecone에서 사용하는 단위
#
# - `index`: 같은 차원과 유사도 기준을 사용하는 vector 검색 공간이다.
# - `namespace`: 하나의 index 안에서 레코드를 논리적으로 나누는 구획이다.
# - 기본 namespace: `namespace`를 지정하지 않았을 때 사용하는 저장 구획이다.
#
# `PineconeVectorStore`는 LangChain과 Pinecone을 연결한다. `Document.page_content`를 embedding하고 vector·원문·metadata를 함께 저장하거나 검색한다.
#
# 이 실습은 기본 namespace를 사용한다. 별도 namespace를 선택하면 저장과 검색에 같은 namespace를 지정해야 한다.

# %% [markdown]
# ### `Document` 목록 만들기
#
# `Document`는 Pinecone에 저장할 검색 단위 하나를 표현한다.
#
# - `page_content`: embedding과 의미 검색에 사용하는 본문이다.
# - `metadata`: 출처 표시와 조건 필터링에 사용하는 부가 정보이다.
# - `documents`: 여러 `Document`를 저장한 목록이다.
#
# 목록의 원소 하나가 Pinecone의 검색 레코드 하나가 된다. 필터에 사용할 metadata key와 자료형은 문서마다 같은 규칙으로 작성하는 것이 좋다.

# %%
from langchain_core.documents import Document

documents = [
    Document(page_content="LangChain은 LLM 기반 애플리케이션을 쉽게 만들 수 있는 프레임워크입니다.", metadata={"source": "https://langchain.com/docs", "author": "alice", "page": 1}),
    Document(page_content="ChromaDB는 오픈소스 벡터 데이터베이스입니다.", metadata={"source": "https://chromadb.org/intro", "license": "MIT", "date": "2024-07_advanced_rag-01"}),
    Document(page_content="파이썬으로 AI 서비스를 개발할 수 있습니다.", metadata={"source": "https://pythonai.co.kr", "editor": "kim", "page": 7}),
    Document(page_content="LLM은 자연어 처리를 위한 대형 언어 모델을 의미합니다.", metadata={"source": "https://llmwiki.com/info", "author": "bob", "version": "v1.1"}),
    Document(page_content="RAG는 검색과 생성의 결합 방식을 제공합니다.", metadata={"source": "https://rag-search.io", "reviewer": "lee", "section": "summary"}),
    Document(page_content="벡터 데이터베이스는 임베딩된 데이터를 효율적으로 검색할 수 있습니다.", metadata={"source": "https://vectorbase.net", "author": "jin", "topic": "vector"}),
    Document(page_content="LangChain을 이용하면 다양한 AI 파이프라인을 구축할 수 있습니다.", metadata={"source": "https://langchain.com/blog", "editor": "sarah", "date": "2024-06-30"}),
    Document(page_content="OpenAI의 GPT 모델은 텍스트 생성에 특화되어 있습니다.", metadata={"source": "https://openai.com/gpt", "lang": "ko", "page": 5}),
    Document(page_content="파이썬은 AI 및 데이터 분석 분야에서 널리 사용되는 언어입니다.", metadata={"source": "https://python.org/usecases", "author": "chun", "updated": "2024-05"}),
    Document(page_content="Streamlit은 파이썬으로 대시보드를 쉽게 만들 수 있는 프레임워크입니다.", metadata={"source": "https://streamlit.io/start", "editor": "park", "date": "2024-04-28"}),
    Document(page_content="Dense Retrieval은 임베딩 벡터를 이용한 검색 방식을 의미합니다.", metadata={"source": "https://retrieval.ai/dense", "type": "tech", "page": 3}),
    Document(page_content="Pandas 라이브러리는 데이터 분석에 자주 사용됩니다.", metadata={"source": "https://pandas.pydata.org/about", "maintainer": "koh", "section": "intro"}),
    Document(page_content="메타데이터 필터링은 검색 결과의 품질을 높여줍니다.", metadata={"source": "https://search.com/metadata", "author": "seo", "feature": "filter"}),
    Document(page_content="SelfQueryRetriever는 자연어 쿼리를 임베딩 쿼리로 변환해줍니다.", metadata={"source": "https://selfquery.ai", "editor": "min", "date": "2024-05-12"}),
    Document(page_content="프롬프트 엔지니어링은 LLM의 성능을 극대화하는 방법입니다.", metadata={"source": "https://prompting.dev/guide", "author": "yang", "topic": "prompt"}),
    Document(page_content="HyDE 기법은 하이브리드 검색에 사용됩니다.", metadata={"source": "https://hyde-tech.com", "reviewer": "kang", "version": "2024.1"}),
    Document(page_content="CoT는 복잡한 문제를 단계적으로 해결하는 프롬프트 기법입니다.", metadata={"source": "https://cotprompt.org", "editor": "jung", "date": "2023-12-01"}),
    Document(page_content="문서 임베딩은 텍스트를 고차원 벡터로 변환하는 과정입니다.", metadata={"source": "https://embedding.ai/intro", "section": "embedding", "author": "song"}),
    Document(page_content="CrewAI는 멀티 에이전트 시스템 구현을 돕는 툴입니다.", metadata={"source": "https://crew.ai/docs", "lang": "ko", "page": 9}),
    Document(page_content="Fine-tuning은 사전학습 모델을 특정 도메인에 맞게 재학습시키는 과정입니다.", metadata={"source": "https://finetune.ai/guide", "editor": "jeon", "date": "2024-01-30"}),
]

# %% [markdown]
# ### 문서를 embedding해 index에 저장하기
#
# `PineconeVectorStore.from_documents()`는 `Document` 목록으로 Vector Store를 만들고 문서를 바로 저장한다.
#
# ### 처리 순서
#
# 1. `OpenAIEmbeddings`가 각 `page_content`를 embedding vector로 변환한다.
# 2. Pinecone에 vector와 원문·metadata를 함께 저장한다.
# 3. 검색에 사용할 `PineconeVectorStore` 객체를 반환한다.
#
# ### 실행 시 주의할 점
#
# - OpenAI Embedding API 비용과 Pinecone 쓰기가 발생한다.
# - 같은 셀을 다시 실행하면 같은 문서가 새 ID로 중복 저장될 수 있다.
# - 실제 적재 개수는 Pinecone index 통계 또는 다음 검색 결과로 확인한다.

# %%
from langchain_openai import OpenAIEmbeddings

from langchain_pinecone import PineconeVectorStore

# 1. Document와 사용자 질문(query)를 벡터화 시킬 Embedding 객체 생성
embeddings = OpenAIEmbeddings(
    model=os.environ['OPENAI_EMBEDDING_MODEL']
)

# 2. Document를 embedding하고 Pinecone에 저장하기
vector_store = PineconeVectorStore.from_documents(
    documents=documents,  # 저장할 문서 목록
    embedding=embeddings, # 문서,query 임베딩 시킬 사용할 객체
    index_name=DEMO_INDEX_NAME # pinecone-first 인덱스 선택
)

# %% [markdown]
# ### 기존 index를 Retriever로 검색하기
#
# `Retriever`는 자연어 query를 받아 관련 `Document`를 찾는 검색 인터페이스이다. 답변을 생성하지 않는다.
#
# ### 검색 흐름
#
# 1. query 문자열을 embedding vector로 변환한다.
# 2. 저장된 문서 vector와 유사도를 비교한다.
# 3. 상위 `k`개의 `Document`를 반환한다.
#
# - 입력: 자연어 query 문자열이다.
# - 출력: `list[Document]`이다.
# - 다음 사용처: 각 문서의 `page_content`를 RAG Prompt의 context로 전달한다.
#
# `as_retriever()`는 Vector Store의 검색 기능을 이 공통 인터페이스로 바꾼다.

# %%
from pinecone import Pinecone

# 1. Pinecone SDK client를 만들고, API키로 계정 인증
pinecone_client = Pinecone(
    api_key=os.environ['PINECONE_API_KEY']
)

# 2. 'pinecone-fist' 인덱스과 연결된 객체 반환받기
pinecone_index = pinecone_client.Index(DEMO_INDEX_NAME)

# 3. 원격 인덱스와 임베딩 객체를 이용해서 LangChain VectorStore 생성
vector_store = PineconeVectorStore(
    embedding=embeddings, # 문서,query 임베딩 시킬 사용할 객체
    index=pinecone_index # pinecone-first 인덱스 선택
)

# 4. LangChain VectorStore -> Retriever로 변환
# - 자연어 query -> Vector Store 검색 -> list[Document] 반환
retriever = vector_store.as_retriever(
    search_type = 'similarity', # query 벡터와 가까운 문서 벡터 검색
    search_kwargs={'k': 3}  # 제일 가까운 문서 벡터 최대 3개
)

# 5. 자연어 query 입력 -> 유사도 높은 Document 반환 받기
retriever_documents = retriever.invoke('벡터 데이터베이스란?')

retriever_documents
# Out:
# [Document(id='69d4949b-6542-4595-87fc-9203bd3fd86b', metadata={'author': 'jin', 'source': 'https://vectorbase.net', 'topic': 'vector'}, page_content='벡터 데이터베이스는 임베딩된 데이터를 효율적으로 검색할 수 있습니다.'),
#  Document(id='262ce3fa-b431-4eb6-ae47-774b2eb258f7', metadata={'date': '2024-07-01', 'license': 'MIT', 'source': 'https://chromadb.org/intro'}, page_content='ChromaDB는 오픈소스 벡터 데이터베이스입니다.'),
#  Document(id='b3c0ff87-fe69-4d27-88e2-b725a97ec6f3', metadata={'page': 3.0, 'source': 'https://retrieval.ai/dense', 'type': 'tech'}, page_content='Dense Retrieval은 임베딩 벡터를 이용한 검색 방식을 의미합니다.')]

# %% [markdown]
# ### 기존 Vector Store에 문서 추가하기
#
# `add_documents()`는 새 `Document`를 현재 Pinecone index에 추가한다.
#
# - 입력: 추가할 `list[Document]`이다.
# - 변환: 각 `page_content`를 같은 embedding 모델로 변환한다.
# - 출력: 저장된 레코드의 ID 목록이다.
# - 다음 사용처: 반환 ID로 레코드를 갱신하거나 삭제할 수 있다.
#
# 이 호출도 원격 쓰기를 수행한다. 반복 실행 전에는 같은 문서가 이미 저장되어 있는지 확인한다.

# %%
new_documents = [
    Document(
        page_content='파이콘은 클라우드에서만 실행 가능하다.',
        metadata={'source': 'https://blog.pinecone.com'}
    )
]

# 연결된 Pinecone index에 문서 추가
# -> 문서 벡터화 수행 후 index에 추가
# -> 결과로 레코드 식별 ID가 반환된다
added_document_ids = vector_store.add_documents(documents=new_documents)

print(added_document_ids)
# Out:
# ['a0ba2a21-4b09-4a42-8566-4a162821c571']

# %% [markdown]
# ## Wine Magazine 리뷰 인덱싱
#
# 이제 [Wine Reviews 데이터셋](https://www.kaggle.com/datasets/christopheiv/winemagdata130k)의 실제 리뷰를 검색 문서로 사용한다.
#
# `CSV 행 → Document → embedding vector → winemag-review-data index`
#
# ### `CSVLoader`가 만드는 값
#
# - `page_content`: CSV 열 이름과 값이 줄 단위로 들어간다.
# - `metadata['source']`: 원본 CSV 경로가 들어간다.
# - `metadata['row']`: 원본 행 번호가 들어간다.
#
# 전체 데이터는 약 13만 행이다. 다운로드 시간, OpenAI embedding 비용, Pinecone 저장 시간, 중복 적재 가능성을 확인한 뒤 실행한다.

# %% [markdown]
# ### 수업용 CSV 내려받기
#
# `gdown`은 공개 Google Drive 파일을 내려받는다.
#
# - 입력: 수업용 Wine Magazine CSV의 파일 ID이다.
# - 출력: 현재 작업 폴더의 `winemag-data-130k-v2.csv`이다.
# - 다음 사용처: `CSVLoader`가 이 파일의 각 행을 읽는다.
#
# 다운로드가 끝나면 출력에 표시된 파일명과 저장 경로를 확인한다.

# %%
import gdown

print(gdown.__version__)
print(gdown.__file__)
# Out:
# 6.1.0
# C:\Users\chzhd\anaconda3\envs\llm_env\Lib\site-packages\gdown\__init__.py

# %%
# !gdown 11OTMjkDgCSixGKSCXON6iijYysUg2_cq
# Out:
# 'gdown'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.

# %%
# !{sys.executable} -m gdown 11OTMjkDgCSixGKSCXON6iijYysUg2_cq

# %% [markdown]
# ### CSV 행을 `Document` 목록으로 변환하기
#
# `CSVLoader`는 CSV의 한 행을 `Document` 하나로 변환한다.
#
# - `file_path`: 앞에서 내려받은 CSV 경로이다.
# - `encoding='utf-8'`: 파일의 문자를 UTF-8 규칙으로 읽는다.
# - `load()` 출력: CSV 행 순서를 유지한 `list[Document]`이다.
#
# 각 `page_content`에는 열 이름과 값이 줄 단위로 들어간다. 이 단계는 로컬 파일만 읽으며 아직 embedding이나 Pinecone 쓰기를 수행하지 않는다.

# %%
from langchain_community.document_loaders import CSVLoader

# 1.CSVLoader로 읽을 파일 경로와 문자 인코딩 설정
loader = CSVLoader(
    file_path='./winemag-data-130k-v2.csv',
    encoding='utf-8'
)

# 2.CSV 데이터 읽어오기(csv 1행 -> Document 1개)
docs = loader.load()

# 3. 읽어온 Document 수 확인
print(len(docs))
# Out:
# C:\Users\chzhd\AppData\Local\Temp\ipykernel_3552\3126064949.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import CSVLoader
# 129971

# %% [markdown]
# ### 변환된 문서 구조 확인하기
#
# 전체 문서를 저장하기 전에 앞의 두 `Document`를 확인한다.
#
# - 자료형: `Document`인지 확인한다.
# - `page_content`: `description`, `title`, `variety` 같은 리뷰 열이 있는지 확인한다.
# - `metadata`: 원본 CSV 경로와 행 번호가 있는지 확인한다.
#
# 이 구조가 맞아야 검색 결과에서 리뷰 내용과 원본 행을 함께 추적할 수 있다.

# %%
for index, document in enumerate(docs[:2]):
    print(f'{index}: {type(document)}')
    print(document)
# Out:
# 0: <class 'langchain_core.documents.base.Document'>
# page_content=': 0
# country: Italy
# description: Aromas include tropical fruit, broom, brimstone and dried herb. The palate isn't overly expressive, offering unripened apple, citrus and dried sage alongside brisk acidity.
# designation: Vulkà Bianco
# points: 87
# price:
# province: Sicily & Sardinia
# region_1: Etna
# region_2:
# taster_name: Kerin O’Keefe
# taster_twitter_handle: @kerinokeefe
# title: Nicosia 2013 Vulkà Bianco  (Etna)
# variety: White Blend
# winery: Nicosia' metadata={'source': './winemag-data-130k-v2.csv', 'row': 0}
# 1: <class 'langchain_core.documents.base.Document'>
# page_content=': 1
# country: Portugal
# description: This is ripe and fruity, a wine that is smooth while still structured. Firm tannins are filled out with juicy red berry fruits and freshened with acidity. It's  already drinkable, although it will certainly be better from 2016.
# designation: Avidagos
# points: 87
# price: 15.0
# province: Douro
# region_1:
# region_2:
# taster_name: Roger Voss
# taster_twitter_handle: @vossroger
# title: Quinta dos Avidagos 2011 Avidagos Red (Douro)
# variety: Portuguese Red
# winery: Quinta dos Avidagos' metadata={'source': './winemag-data-130k-v2.csv', 'row': 1}

# %% [markdown]
# ### 실제 리뷰를 배치로 적재하기
#
# **Batch**는 전체 문서를 작은 묶음으로 나누어 처리하는 방법이다. 여기서는 `docs`를 100개씩 나누어 `winemag-review-data` index의 기본 namespace에 저장한다.
#
# ### 처리 순서
#
# 1. 와인 index와 embedding 모델을 연결한다.
# 2. `range()`와 slice로 `docs`를 100개씩 나눈다.
# 3. 각 batch를 `add_documents()`에 전달한다.
# 4. 문서 본문을 embedding하고 Pinecone에 upsert한다.
#
# ### 배치를 사용하는 이유
#
# - 한 요청이 사용하는 메모리와 전송량을 제한한다.
# - 오류가 발생한 batch 위치를 출력으로 확인할 수 있다.
# - 마지막 batch는 100개보다 작아도 그대로 처리할 수 있다.
#
# 이 셀은 장시간 실행과 외부 API 비용을 발생시킨다. 재실행하면 이미 저장된 리뷰가 중복될 수 있다.

# %%
batch_size = 100

# 1. 임베딩 객체 준비
embeddings = OpenAIEmbeddings(
    model=os.environ['OPENAI_EMBEDDING_MODEL']
)

# 2. 'winemag-review-data' 인덱스와 임베딩 객체를 연결
wine_vector_store = PineconeVectorStore.from_documents(
    documents=[], # 아직 실제 문서 전달 X
    embedding=embeddings,
    index_name=WINE_INDEX_NAME
)

# 3. 배치 크기만큼으로 docs를 나누어 추가
for start in range(21300, len(docs), batch_size):

    batch = docs[start:start + batch_size]
    print(f'index: {start}, batch: {len(batch)}')

    # 4. index에 document추가
    wine_vector_store.add_documents(documents=batch)
# Out:
# index: 21300, batch: 100
# index: 21400, batch: 100
# index: 21500, batch: 100
# index: 21600, batch: 100
# index: 21700, batch: 100
# index: 21800, batch: 100
# index: 21900, batch: 100
# index: 22000, batch: 100
# index: 22100, batch: 100
# index: 22200, batch: 100
# index: 22300, batch: 100
# index: 22400, batch: 100
# index: 22500, batch: 100
# index: 22600, batch: 100
# index: 22700, batch: 100
# index: 22800, batch: 100
# index: 22900, batch: 100
# index: 23000, batch: 100
# index: 23100, batch: 100
# index: 23200, batch: 100
# index: 23300, batch: 100
# index: 23400, batch: 100
# index: 23500, batch: 100
# index: 23600, batch: 100
# index: 23700, batch: 100
# index: 23800, batch: 100
# index: 23900, batch: 100
# index: 24000, batch: 100
# index: 24100, batch: 100
# index: 24200, batch: 100
# index: 24300, batch: 100
# index: 24400, batch: 100
# index: 24500, batch: 100
# index: 24600, batch: 100
# index: 24700, batch: 100
# index: 24800, batch: 100
# index: 24900, batch: 100
# index: 25000, batch: 100
# index: 25100, batch: 100
# index: 25200, batch: 100
# index: 25300, batch: 100
# index: 25400, batch: 100
# index: 25500, batch: 100
# index: 25600, batch: 100
# index: 25700, batch: 100
# index: 25800, batch: 100
# index: 25900, batch: 100
# index: 26000, batch: 100
# index: 26100, batch: 100
# index: 26200, batch: 100
# index: 26300, batch: 100
# index: 26400, batch: 100
# index: 26500, batch: 100
# index: 26600, batch: 100
# index: 26700, batch: 100
# index: 26800, batch: 100
# index: 26900, batch: 100
# index: 27000, batch: 100
# index: 27100, batch: 100
# index: 27200, batch: 100
# index: 27300, batch: 100
# index: 27400, batch: 100
# index: 27500, batch: 100
# index: 27600, batch: 100
# index: 27700, batch: 100
# index: 27800, batch: 100
# index: 27900, batch: 100
# index: 28000, batch: 100
# index: 28100, batch: 100
# index: 28200, batch: 100
# index: 28300, batch: 100
# index: 28400, batch: 100
# index: 28500, batch: 100
# index: 28600, batch: 100
# index: 28700, batch: 100
# index: 28800, batch: 100
# index: 28900, batch: 100
# index: 29000, batch: 100
# index: 29100, batch: 100
# index: 29200, batch: 100
# index: 29300, batch: 100
# index: 29400, batch: 100
# index: 29500, batch: 100
# index: 29600, batch: 100
# index: 29700, batch: 100
# index: 29800, batch: 100
# index: 29900, batch: 100
# index: 30000, batch: 100
# index: 30100, batch: 100
# index: 30200, batch: 100
# index: 30300, batch: 100
# index: 30400, batch: 100
# index: 30500, batch: 100
# index: 30600, batch: 100
# index: 30700, batch: 100
# index: 30800, batch: 100
# index: 30900, batch: 100
# index: 31000, batch: 100
# index: 31100, batch: 100
# index: 31200, batch: 100
# index: 31300, batch: 100
# index: 31400, batch: 100
# index: 31500, batch: 100
# index: 31600, batch: 100
# index: 31700, batch: 100
# index: 31800, batch: 100
# index: 31900, batch: 100
# index: 32000, batch: 100
# index: 32100, batch: 100
# index: 32200, batch: 100
# index: 32300, batch: 100
# index: 32400, batch: 100
# index: 32500, batch: 100
# index: 32600, batch: 100
# index: 32700, batch: 100
# index: 32800, batch: 100
# index: 32900, batch: 100
# index: 33000, batch: 100
# index: 33100, batch: 100
# index: 33200, batch: 100
# index: 33300, batch: 100
# index: 33400, batch: 100
# index: 33500, batch: 100
# index: 33600, batch: 100
# index: 33700, batch: 100
# index: 33800, batch: 100
# index: 33900, batch: 100
# index: 34000, batch: 100
# index: 34100, batch: 100
# index: 34200, batch: 100
# index: 34300, batch: 100
# index: 34400, batch: 100
# index: 34500, batch: 100
# index: 34600, batch: 100
# index: 34700, batch: 100
# index: 34800, batch: 100
# index: 34900, batch: 100
# index: 35000, batch: 100
# index: 35100, batch: 100
# index: 35200, batch: 100
# index: 35300, batch: 100
# index: 35400, batch: 100
# index: 35500, batch: 100
# index: 35600, batch: 100
# index: 35700, batch: 100
# index: 35800, batch: 100
# index: 35900, batch: 100
# index: 36000, batch: 100
# index: 36100, batch: 100
# index: 36200, batch: 100
# index: 36300, batch: 100
# index: 36400, batch: 100
# index: 36500, batch: 100
# index: 36600, batch: 100
# index: 36700, batch: 100
# index: 36800, batch: 100
# index: 36900, batch: 100
# index: 37000, batch: 100
# index: 37100, batch: 100
# index: 37200, batch: 100
# index: 37300, batch: 100
# index: 37400, batch: 100
# index: 37500, batch: 100
# index: 37600, batch: 100
# index: 37700, batch: 100
# index: 37800, batch: 100
# index: 37900, batch: 100
# index: 38000, batch: 100
# index: 38100, batch: 100
# index: 38200, batch: 100
# index: 38300, batch: 100
# index: 38400, batch: 100
# index: 38500, batch: 100
# index: 38600, batch: 100
# index: 38700, batch: 100
# index: 38800, batch: 100
# index: 38900, batch: 100
# index: 39000, batch: 100
# index: 39100, batch: 100
# index: 39200, batch: 100
# index: 39300, batch: 100
# index: 39400, batch: 100
# index: 39500, batch: 100
# index: 39600, batch: 100
# index: 39700, batch: 100
# index: 39800, batch: 100
# index: 39900, batch: 100
# index: 40000, batch: 100
# index: 40100, batch: 100
# index: 40200, batch: 100
# index: 40300, batch: 100
# index: 40400, batch: 100
# index: 40500, batch: 100
# index: 40600, batch: 100
# index: 40700, batch: 100
# index: 40800, batch: 100
# index: 40900, batch: 100
# index: 41000, batch: 100
# index: 41100, batch: 100
# index: 41200, batch: 100
# index: 41300, batch: 100
# index: 41400, batch: 100
# index: 41500, batch: 100
# index: 41600, batch: 100
# index: 41700, batch: 100
# index: 41800, batch: 100
# index: 41900, batch: 100
# index: 42000, batch: 100
# index: 42100, batch: 100
# index: 42200, batch: 100
# index: 42300, batch: 100
# index: 42400, batch: 100
# index: 42500, batch: 100
# index: 42600, batch: 100
# index: 42700, batch: 100
# index: 42800, batch: 100
# index: 42900, batch: 100
# index: 43000, batch: 100
# index: 43100, batch: 100
# index: 43200, batch: 100
# index: 43300, batch: 100
# index: 43400, batch: 100
# index: 43500, batch: 100
# index: 43600, batch: 100
# index: 43700, batch: 100
# index: 43800, batch: 100
# index: 43900, batch: 100
# index: 44000, batch: 100
# index: 44100, batch: 100
# index: 44200, batch: 100
# index: 44300, batch: 100
# index: 44400, batch: 100
# index: 44500, batch: 100
# index: 44600, batch: 100
# index: 44700, batch: 100
# index: 44800, batch: 100
# index: 44900, batch: 100
# index: 45000, batch: 100
# index: 45100, batch: 100
# index: 45200, batch: 100
# index: 45300, batch: 100
# index: 45400, batch: 100
# index: 45500, batch: 100
# index: 45600, batch: 100
# index: 45700, batch: 100
# index: 45800, batch: 100
# index: 45900, batch: 100
# index: 46000, batch: 100
# index: 46100, batch: 100
# index: 46200, batch: 100
# index: 46300, batch: 100
# index: 46400, batch: 100
# index: 46500, batch: 100
# index: 46600, batch: 100
# index: 46700, batch: 100
# index: 46800, batch: 100
# index: 46900, batch: 100
# index: 47000, batch: 100
# index: 47100, batch: 100
# index: 47200, batch: 100
# index: 47300, batch: 100
# index: 47400, batch: 100
# index: 47500, batch: 100
# index: 47600, batch: 100
# index: 47700, batch: 100
# index: 47800, batch: 100
# index: 47900, batch: 100
# index: 48000, batch: 100
# index: 48100, batch: 100
# index: 48200, batch: 100
# index: 48300, batch: 100
# index: 48400, batch: 100
# index: 48500, batch: 100
# index: 48600, batch: 100
# index: 48700, batch: 100
# index: 48800, batch: 100
# index: 48900, batch: 100
# index: 49000, batch: 100
# index: 49100, batch: 100
# index: 49200, batch: 100
# index: 49300, batch: 100
# index: 49400, batch: 100
# index: 49500, batch: 100
# index: 49600, batch: 100
# index: 49700, batch: 100
# index: 49800, batch: 100
# index: 49900, batch: 100
# index: 50000, batch: 100
# index: 50100, batch: 100
# index: 50200, batch: 100
# index: 50300, batch: 100
# index: 50400, batch: 100
# index: 50500, batch: 100
# index: 50600, batch: 100
# index: 50700, batch: 100
# index: 50800, batch: 100
# index: 50900, batch: 100
# index: 51000, batch: 100
# index: 51100, batch: 100
# index: 51200, batch: 100
# index: 51300, batch: 100
# index: 51400, batch: 100
# index: 51500, batch: 100
# index: 51600, batch: 100
# index: 51700, batch: 100
# index: 51800, batch: 100
# index: 51900, batch: 100
# index: 52000, batch: 100
# index: 52100, batch: 100
# index: 52200, batch: 100
# index: 52300, batch: 100
# index: 52400, batch: 100
# index: 52500, batch: 100
# index: 52600, batch: 100
# index: 52700, batch: 100
# index: 52800, batch: 100
# index: 52900, batch: 100
# index: 53000, batch: 100
# index: 53100, batch: 100
# index: 53200, batch: 100
# index: 53300, batch: 100
# index: 53400, batch: 100
# index: 53500, batch: 100
# index: 53600, batch: 100
# index: 53700, batch: 100
# index: 53800, batch: 100
# index: 53900, batch: 100
# index: 54000, batch: 100
# index: 54100, batch: 100
# index: 54200, batch: 100
# index: 54300, batch: 100
# index: 54400, batch: 100
# index: 54500, batch: 100
# index: 54600, batch: 100
# index: 54700, batch: 100
# index: 54800, batch: 100
# index: 54900, batch: 100
# index: 55000, batch: 100
# index: 55100, batch: 100
# index: 55200, batch: 100
# index: 55300, batch: 100
# index: 55400, batch: 100
# index: 55500, batch: 100
# index: 55600, batch: 100
# index: 55700, batch: 100
# index: 55800, batch: 100
# index: 55900, batch: 100
# index: 56000, batch: 100
# index: 56100, batch: 100
# index: 56200, batch: 100
# index: 56300, batch: 100
# index: 56400, batch: 100
# index: 56500, batch: 100
# index: 56600, batch: 100
# index: 56700, batch: 100
# index: 56800, batch: 100
# index: 56900, batch: 100
# index: 57000, batch: 100
# index: 57100, batch: 100
# index: 57200, batch: 100
# index: 57300, batch: 100
# index: 57400, batch: 100
# index: 57500, batch: 100
# index: 57600, batch: 100
# index: 57700, batch: 100
# index: 57800, batch: 100
# index: 57900, batch: 100
# index: 58000, batch: 100
# index: 58100, batch: 100
# index: 58200, batch: 100
# index: 58300, batch: 100
# index: 58400, batch: 100
# index: 58500, batch: 100
# index: 58600, batch: 100
# index: 58700, batch: 100
# index: 58800, batch: 100
# index: 58900, batch: 100
# index: 59000, batch: 100
# index: 59100, batch: 100
# index: 59200, batch: 100
# index: 59300, batch: 100
# index: 59400, batch: 100
# index: 59500, batch: 100
# index: 59600, batch: 100
# index: 59700, batch: 100
# index: 59800, batch: 100
# index: 59900, batch: 100
# index: 60000, batch: 100
# index: 60100, batch: 100
# index: 60200, batch: 100
# index: 60300, batch: 100
# index: 60400, batch: 100
# index: 60500, batch: 100
# index: 60600, batch: 100
# index: 60700, batch: 100
# index: 60800, batch: 100
# index: 60900, batch: 100
# index: 61000, batch: 100
# index: 61100, batch: 100
# index: 61200, batch: 100
# index: 61300, batch: 100
# index: 61400, batch: 100
# index: 61500, batch: 100
# index: 61600, batch: 100
# index: 61700, batch: 100
# index: 61800, batch: 100
# index: 61900, batch: 100
# index: 62000, batch: 100
# index: 62100, batch: 100
# index: 62200, batch: 100
# index: 62300, batch: 100
# index: 62400, batch: 100
# index: 62500, batch: 100
# index: 62600, batch: 100
# index: 62700, batch: 100
# index: 62800, batch: 100
# index: 62900, batch: 100
# index: 63000, batch: 100
# index: 63100, batch: 100
# index: 63200, batch: 100
# index: 63300, batch: 100
# index: 63400, batch: 100
# index: 63500, batch: 100
# index: 63600, batch: 100
# index: 63700, batch: 100
# index: 63800, batch: 100
# index: 63900, batch: 100
# index: 64000, batch: 100
# index: 64100, batch: 100
# index: 64200, batch: 100
# index: 64300, batch: 100
# index: 64400, batch: 100
# index: 64500, batch: 100
# index: 64600, batch: 100
# index: 64700, batch: 100
# index: 64800, batch: 100
# index: 64900, batch: 100
# index: 65000, batch: 100
# index: 65100, batch: 100
# index: 65200, batch: 100
# index: 65300, batch: 100
# index: 65400, batch: 100
# index: 65500, batch: 100
# index: 65600, batch: 100
# index: 65700, batch: 100
# index: 65800, batch: 100
# index: 65900, batch: 100
# index: 66000, batch: 100
# index: 66100, batch: 100
# index: 66200, batch: 100
# index: 66300, batch: 100
# index: 66400, batch: 100
# index: 66500, batch: 100
# index: 66600, batch: 100
# index: 66700, batch: 100
# index: 66800, batch: 100
# index: 66900, batch: 100
# index: 67000, batch: 100
# index: 67100, batch: 100
# index: 67200, batch: 100
# index: 67300, batch: 100
# index: 67400, batch: 100
# index: 67500, batch: 100
# index: 67600, batch: 100
# index: 67700, batch: 100
# index: 67800, batch: 100
# index: 67900, batch: 100
# index: 68000, batch: 100
# index: 68100, batch: 100
# index: 68200, batch: 100
# index: 68300, batch: 100
# index: 68400, batch: 100
# index: 68500, batch: 100
# index: 68600, batch: 100
# index: 68700, batch: 100
# index: 68800, batch: 100
# index: 68900, batch: 100
# index: 69000, batch: 100
# index: 69100, batch: 100
# index: 69200, batch: 100
# index: 69300, batch: 100
# index: 69400, batch: 100
# index: 69500, batch: 100
# index: 69600, batch: 100
# index: 69700, batch: 100
# index: 69800, batch: 100
# index: 69900, batch: 100
# index: 70000, batch: 100
# index: 70100, batch: 100
# index: 70200, batch: 100
# index: 70300, batch: 100
# index: 70400, batch: 100
# index: 70500, batch: 100
# index: 70600, batch: 100
# index: 70700, batch: 100
# index: 70800, batch: 100
# index: 70900, batch: 100
# index: 71000, batch: 100
# index: 71100, batch: 100
# index: 71200, batch: 100
# index: 71300, batch: 100
# index: 71400, batch: 100
# index: 71500, batch: 100
# index: 71600, batch: 100
# index: 71700, batch: 100
# index: 71800, batch: 100
# index: 71900, batch: 100
# index: 72000, batch: 100
# index: 72100, batch: 100
# index: 72200, batch: 100
# index: 72300, batch: 100
# index: 72400, batch: 100
# index: 72500, batch: 100
# index: 72600, batch: 100
# index: 72700, batch: 100
# index: 72800, batch: 100
# index: 72900, batch: 100
# index: 73000, batch: 100
# index: 73100, batch: 100
# index: 73200, batch: 100
# index: 73300, batch: 100
# index: 73400, batch: 100
# index: 73500, batch: 100
# index: 73600, batch: 100
# index: 73700, batch: 100
# index: 73800, batch: 100
# index: 73900, batch: 100
# index: 74000, batch: 100
# index: 74100, batch: 100
# index: 74200, batch: 100
# index: 74300, batch: 100
# index: 74400, batch: 100
# index: 74500, batch: 100
# index: 74600, batch: 100
# index: 74700, batch: 100
# index: 74800, batch: 100
# index: 74900, batch: 100
# index: 75000, batch: 100
# index: 75100, batch: 100
# index: 75200, batch: 100
# index: 75300, batch: 100
# index: 75400, batch: 100
# index: 75500, batch: 100
# index: 75600, batch: 100
# index: 75700, batch: 100
# index: 75800, batch: 100
# index: 75900, batch: 100
# index: 76000, batch: 100
# index: 76100, batch: 100
# index: 76200, batch: 100
# index: 76300, batch: 100
# index: 76400, batch: 100
# index: 76500, batch: 100
# index: 76600, batch: 100
# index: 76700, batch: 100
# index: 76800, batch: 100
# index: 76900, batch: 100
# index: 77000, batch: 100
# index: 77100, batch: 100
# index: 77200, batch: 100
# index: 77300, batch: 100
# index: 77400, batch: 100
# index: 77500, batch: 100
# index: 77600, batch: 100
# index: 77700, batch: 100
# index: 77800, batch: 100
# index: 77900, batch: 100
# index: 78000, batch: 100
# index: 78100, batch: 100
# index: 78200, batch: 100
# index: 78300, batch: 100
# index: 78400, batch: 100
# index: 78500, batch: 100
# index: 78600, batch: 100
# index: 78700, batch: 100
# index: 78800, batch: 100
# index: 78900, batch: 100
# index: 79000, batch: 100
# index: 79100, batch: 100
# index: 79200, batch: 100
# index: 79300, batch: 100
# index: 79400, batch: 100
# index: 79500, batch: 100
# index: 79600, batch: 100
# index: 79700, batch: 100
# index: 79800, batch: 100
# index: 79900, batch: 100
# index: 80000, batch: 100
# index: 80100, batch: 100
# index: 80200, batch: 100
# index: 80300, batch: 100
# index: 80400, batch: 100
# index: 80500, batch: 100
# index: 80600, batch: 100
# index: 80700, batch: 100
# index: 80800, batch: 100
# index: 80900, batch: 100
# index: 81000, batch: 100
# index: 81100, batch: 100
# index: 81200, batch: 100
# index: 81300, batch: 100
# index: 81400, batch: 100
# index: 81500, batch: 100
# index: 81600, batch: 100
# index: 81700, batch: 100
# index: 81800, batch: 100
# index: 81900, batch: 100
# index: 82000, batch: 100
# index: 82100, batch: 100
# index: 82200, batch: 100
# index: 82300, batch: 100
# index: 82400, batch: 100
# index: 82500, batch: 100
# index: 82600, batch: 100
# index: 82700, batch: 100
# index: 82800, batch: 100
# index: 82900, batch: 100
# index: 83000, batch: 100
# index: 83100, batch: 100
# index: 83200, batch: 100
# index: 83300, batch: 100
# index: 83400, batch: 100
# index: 83500, batch: 100
# index: 83600, batch: 100
# index: 83700, batch: 100
# index: 83800, batch: 100
# index: 83900, batch: 100
# index: 84000, batch: 100
# index: 84100, batch: 100
# index: 84200, batch: 100
# index: 84300, batch: 100
# index: 84400, batch: 100
# index: 84500, batch: 100
# index: 84600, batch: 100
# index: 84700, batch: 100
# index: 84800, batch: 100
# index: 84900, batch: 100
# index: 85000, batch: 100
# index: 85100, batch: 100
# index: 85200, batch: 100
# index: 85300, batch: 100
# index: 85400, batch: 100
# index: 85500, batch: 100
# index: 85600, batch: 100
# index: 85700, batch: 100
# index: 85800, batch: 100
# index: 85900, batch: 100
# index: 86000, batch: 100
# index: 86100, batch: 100
# index: 86200, batch: 100
# index: 86300, batch: 100
# index: 86400, batch: 100
# index: 86500, batch: 100
# index: 86600, batch: 100
# index: 86700, batch: 100
# index: 86800, batch: 100
# index: 86900, batch: 100
# index: 87000, batch: 100
# index: 87100, batch: 100
# index: 87200, batch: 100
# index: 87300, batch: 100
# index: 87400, batch: 100
# index: 87500, batch: 100
# index: 87600, batch: 100
# index: 87700, batch: 100
# index: 87800, batch: 100
# index: 87900, batch: 100
# index: 88000, batch: 100
# index: 88100, batch: 100
# index: 88200, batch: 100
# index: 88300, batch: 100
# index: 88400, batch: 100
# index: 88500, batch: 100
# index: 88600, batch: 100
# index: 88700, batch: 100
# index: 88800, batch: 100
# index: 88900, batch: 100
# index: 89000, batch: 100
# index: 89100, batch: 100
# index: 89200, batch: 100
# index: 89300, batch: 100
# index: 89400, batch: 100
# index: 89500, batch: 100
# index: 89600, batch: 100
# index: 89700, batch: 100
# index: 89800, batch: 100
# index: 89900, batch: 100
# index: 90000, batch: 100
# index: 90100, batch: 100
# index: 90200, batch: 100
# index: 90300, batch: 100
# index: 90400, batch: 100
# index: 90500, batch: 100
# index: 90600, batch: 100
# index: 90700, batch: 100
# index: 90800, batch: 100
# index: 90900, batch: 100
# index: 91000, batch: 100
# index: 91100, batch: 100
# index: 91200, batch: 100
# index: 91300, batch: 100
# index: 91400, batch: 100
# index: 91500, batch: 100
# index: 91600, batch: 100
# index: 91700, batch: 100
# index: 91800, batch: 100
# index: 91900, batch: 100
# index: 92000, batch: 100
# index: 92100, batch: 100
# index: 92200, batch: 100
# index: 92300, batch: 100
# index: 92400, batch: 100
# index: 92500, batch: 100
# index: 92600, batch: 100
# index: 92700, batch: 100
# index: 92800, batch: 100
# index: 92900, batch: 100
# index: 93000, batch: 100
# index: 93100, batch: 100
# index: 93200, batch: 100
# index: 93300, batch: 100
# index: 93400, batch: 100
# index: 93500, batch: 100
# index: 93600, batch: 100
# index: 93700, batch: 100
# index: 93800, batch: 100
# index: 93900, batch: 100
# index: 94000, batch: 100
# index: 94100, batch: 100
# index: 94200, batch: 100
# index: 94300, batch: 100
# index: 94400, batch: 100
# index: 94500, batch: 100
# index: 94600, batch: 100
# index: 94700, batch: 100
# index: 94800, batch: 100
# index: 94900, batch: 100
# index: 95000, batch: 100
# index: 95100, batch: 100
# index: 95200, batch: 100
# index: 95300, batch: 100
# index: 95400, batch: 100
# index: 95500, batch: 100
# index: 95600, batch: 100
# index: 95700, batch: 100
# index: 95800, batch: 100
# index: 95900, batch: 100
# index: 96000, batch: 100
# index: 96100, batch: 100
# index: 96200, batch: 100
# index: 96300, batch: 100
# index: 96400, batch: 100
# index: 96500, batch: 100
# index: 96600, batch: 100
# index: 96700, batch: 100
# index: 96800, batch: 100
# index: 96900, batch: 100
# index: 97000, batch: 100
# index: 97100, batch: 100
# index: 97200, batch: 100
# index: 97300, batch: 100
# index: 97400, batch: 100
# index: 97500, batch: 100
# index: 97600, batch: 100
# index: 97700, batch: 100
# index: 97800, batch: 100
# index: 97900, batch: 100
# index: 98000, batch: 100
# index: 98100, batch: 100
# index: 98200, batch: 100
# index: 98300, batch: 100
# index: 98400, batch: 100
# index: 98500, batch: 100
# index: 98600, batch: 100
# index: 98700, batch: 100
# index: 98800, batch: 100
# index: 98900, batch: 100
# index: 99000, batch: 100
# index: 99100, batch: 100
# index: 99200, batch: 100
# index: 99300, batch: 100
# index: 99400, batch: 100
# index: 99500, batch: 100
# index: 99600, batch: 100
# index: 99700, batch: 100
# index: 99800, batch: 100
# index: 99900, batch: 100
# index: 100000, batch: 100
# index: 100100, batch: 100
# index: 100200, batch: 100
# index: 100300, batch: 100
# index: 100400, batch: 100
# index: 100500, batch: 100
# index: 100600, batch: 100
# index: 100700, batch: 100
# index: 100800, batch: 100
# index: 100900, batch: 100
# index: 101000, batch: 100
# index: 101100, batch: 100
# index: 101200, batch: 100
# index: 101300, batch: 100
# index: 101400, batch: 100
# index: 101500, batch: 100
# index: 101600, batch: 100
# index: 101700, batch: 100
# index: 101800, batch: 100
# index: 101900, batch: 100
# index: 102000, batch: 100
# index: 102100, batch: 100
# index: 102200, batch: 100
# index: 102300, batch: 100
# index: 102400, batch: 100
# index: 102500, batch: 100
# index: 102600, batch: 100
# index: 102700, batch: 100
# index: 102800, batch: 100
# index: 102900, batch: 100
# index: 103000, batch: 100
# index: 103100, batch: 100
# index: 103200, batch: 100
# index: 103300, batch: 100
# index: 103400, batch: 100
# index: 103500, batch: 100
# index: 103600, batch: 100
# index: 103700, batch: 100
# index: 103800, batch: 100
# index: 103900, batch: 100
# index: 104000, batch: 100
# index: 104100, batch: 100
# index: 104200, batch: 100
# index: 104300, batch: 100
# index: 104400, batch: 100
# index: 104500, batch: 100
# index: 104600, batch: 100
# index: 104700, batch: 100
# index: 104800, batch: 100
# index: 104900, batch: 100
# index: 105000, batch: 100
# index: 105100, batch: 100
# index: 105200, batch: 100
# index: 105300, batch: 100
# index: 105400, batch: 100
# index: 105500, batch: 100
# index: 105600, batch: 100
# index: 105700, batch: 100
# index: 105800, batch: 100
# index: 105900, batch: 100
# index: 106000, batch: 100
# index: 106100, batch: 100
# index: 106200, batch: 100
# index: 106300, batch: 100
# index: 106400, batch: 100
# index: 106500, batch: 100
# index: 106600, batch: 100
# index: 106700, batch: 100
# index: 106800, batch: 100
# index: 106900, batch: 100
# index: 107000, batch: 100
# index: 107100, batch: 100
# index: 107200, batch: 100
# index: 107300, batch: 100
# index: 107400, batch: 100
# index: 107500, batch: 100
# index: 107600, batch: 100
# index: 107700, batch: 100
# index: 107800, batch: 100
# index: 107900, batch: 100
# index: 108000, batch: 100
# index: 108100, batch: 100
# index: 108200, batch: 100
# index: 108300, batch: 100
# index: 108400, batch: 100
# index: 108500, batch: 100
# index: 108600, batch: 100
# index: 108700, batch: 100
# index: 108800, batch: 100
# index: 108900, batch: 100
# index: 109000, batch: 100
# index: 109100, batch: 100
# index: 109200, batch: 100
# index: 109300, batch: 100
# index: 109400, batch: 100
# index: 109500, batch: 100
# index: 109600, batch: 100
# index: 109700, batch: 100
# index: 109800, batch: 100
# index: 109900, batch: 100
# index: 110000, batch: 100
# index: 110100, batch: 100
# index: 110200, batch: 100
# index: 110300, batch: 100
# index: 110400, batch: 100
# index: 110500, batch: 100
# index: 110600, batch: 100
# index: 110700, batch: 100
# index: 110800, batch: 100
# index: 110900, batch: 100
# index: 111000, batch: 100
# index: 111100, batch: 100
# index: 111200, batch: 100
# index: 111300, batch: 100
# index: 111400, batch: 100
# index: 111500, batch: 100
# index: 111600, batch: 100
# index: 111700, batch: 100
# index: 111800, batch: 100
# index: 111900, batch: 100
# index: 112000, batch: 100
# index: 112100, batch: 100
# index: 112200, batch: 100
# index: 112300, batch: 100
# index: 112400, batch: 100
# index: 112500, batch: 100
# index: 112600, batch: 100
# index: 112700, batch: 100
# index: 112800, batch: 100
# index: 112900, batch: 100
# index: 113000, batch: 100
# index: 113100, batch: 100
# index: 113200, batch: 100
# index: 113300, batch: 100
# index: 113400, batch: 100
# index: 113500, batch: 100
# index: 113600, batch: 100
# index: 113700, batch: 100
# index: 113800, batch: 100
# index: 113900, batch: 100
# index: 114000, batch: 100
# index: 114100, batch: 100
# index: 114200, batch: 100
# index: 114300, batch: 100
# index: 114400, batch: 100
# index: 114500, batch: 100
# index: 114600, batch: 100
# index: 114700, batch: 100
# index: 114800, batch: 100
# index: 114900, batch: 100
# index: 115000, batch: 100
# index: 115100, batch: 100
# index: 115200, batch: 100
# index: 115300, batch: 100
# index: 115400, batch: 100
# index: 115500, batch: 100
# index: 115600, batch: 100
# index: 115700, batch: 100
# index: 115800, batch: 100
# index: 115900, batch: 100
# index: 116000, batch: 100
# index: 116100, batch: 100
# index: 116200, batch: 100
# index: 116300, batch: 100
# index: 116400, batch: 100
# index: 116500, batch: 100
# index: 116600, batch: 100
# index: 116700, batch: 100
# index: 116800, batch: 100
# index: 116900, batch: 100
# index: 117000, batch: 100
# index: 117100, batch: 100
# index: 117200, batch: 100
# index: 117300, batch: 100
# index: 117400, batch: 100
# index: 117500, batch: 100
# index: 117600, batch: 100
# index: 117700, batch: 100
# index: 117800, batch: 100
# index: 117900, batch: 100
# index: 118000, batch: 100
# index: 118100, batch: 100
# index: 118200, batch: 100
# index: 118300, batch: 100
# index: 118400, batch: 100
# index: 118500, batch: 100
# index: 118600, batch: 100
# index: 118700, batch: 100
# index: 118800, batch: 100
# index: 118900, batch: 100
# index: 119000, batch: 100
# index: 119100, batch: 100
# index: 119200, batch: 100
# index: 119300, batch: 100
# index: 119400, batch: 100
# index: 119500, batch: 100
# index: 119600, batch: 100
# index: 119700, batch: 100
# index: 119800, batch: 100
# index: 119900, batch: 100
# index: 120000, batch: 100
# index: 120100, batch: 100
# index: 120200, batch: 100
# index: 120300, batch: 100
# index: 120400, batch: 100
# index: 120500, batch: 100
# index: 120600, batch: 100
# index: 120700, batch: 100
# index: 120800, batch: 100
# index: 120900, batch: 100
# index: 121000, batch: 100
# index: 121100, batch: 100
# index: 121200, batch: 100
# index: 121300, batch: 100
# index: 121400, batch: 100
# index: 121500, batch: 100
# index: 121600, batch: 100
# index: 121700, batch: 100
# index: 121800, batch: 100
# index: 121900, batch: 100
# index: 122000, batch: 100
# index: 122100, batch: 100
# index: 122200, batch: 100
# index: 122300, batch: 100
# index: 122400, batch: 100
# index: 122500, batch: 100
# index: 122600, batch: 100
# index: 122700, batch: 100
# index: 122800, batch: 100
# index: 122900, batch: 100
# index: 123000, batch: 100
# index: 123100, batch: 100
# index: 123200, batch: 100
# index: 123300, batch: 100
# index: 123400, batch: 100
# index: 123500, batch: 100
# index: 123600, batch: 100
# index: 123700, batch: 100
# index: 123800, batch: 100
# index: 123900, batch: 100
# index: 124000, batch: 100
# index: 124100, batch: 100
# index: 124200, batch: 100
# index: 124300, batch: 100
# index: 124400, batch: 100
# index: 124500, batch: 100
# index: 124600, batch: 100
# index: 124700, batch: 100
# index: 124800, batch: 100
# index: 124900, batch: 100
# index: 125000, batch: 100
# index: 125100, batch: 100
# index: 125200, batch: 100
# index: 125300, batch: 100
# index: 125400, batch: 100
# index: 125500, batch: 100
# index: 125600, batch: 100
# index: 125700, batch: 100
# index: 125800, batch: 100
# index: 125900, batch: 100
# index: 126000, batch: 100
# index: 126100, batch: 100
# index: 126200, batch: 100
# index: 126300, batch: 100
# index: 126400, batch: 100
# index: 126500, batch: 100
# index: 126600, batch: 100
# index: 126700, batch: 100
# index: 126800, batch: 100
# index: 126900, batch: 100
# index: 127000, batch: 100
# index: 127100, batch: 100
# index: 127200, batch: 100
# index: 127300, batch: 100
# index: 127400, batch: 100
# index: 127500, batch: 100
# index: 127600, batch: 100
# index: 127700, batch: 100
# index: 127800, batch: 100
# index: 127900, batch: 100
# index: 128000, batch: 100
# index: 128100, batch: 100
# index: 128200, batch: 100
# index: 128300, batch: 100
# index: 128400, batch: 100
# index: 128500, batch: 100
# index: 128600, batch: 100
# index: 128700, batch: 100
# index: 128800, batch: 100
# index: 128900, batch: 100
# index: 129000, batch: 100
# index: 129100, batch: 100
# index: 129200, batch: 100
# index: 129300, batch: 100
# index: 129400, batch: 100
# index: 129500, batch: 100
# index: 129600, batch: 100
# index: 129700, batch: 100
# index: 129800, batch: 100
# index: 129900, batch: 71

# %% [markdown]
# ## 직접 적용해 보기
#
# 작은 리뷰 범위를 별도의 연습용 namespace에 적재하고 검색하는 코드를 완성한다. 기존 기본 namespace를 반복 적재하지 않도록 새로운 namespace 이름을 먼저 정한다.
#
# 1. `docs`에서 앞부분의 제한된 범위를 선택한다.
# 2. `add_documents()`에 선택한 문서와 연습용 namespace를 전달한다.
# 3. 같은 index·embedding·namespace를 사용하는 Retriever를 만든다.
# 4. 음식 풍미 query를 입력하고 반환된 `list[Document]`의 `page_content`와 `metadata`를 확인한다.
#
# 완성 조건은 선택한 범위의 실제 리뷰가 검색되고, 검색 Document의 metadata로 원본 CSV 행을 추적할 수 있는 것이다. namespace 값과 검색 개수 `k`는 직접 결정한다.
